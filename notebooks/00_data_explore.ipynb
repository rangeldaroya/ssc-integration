# %%
import rasterio
import os
import numpy as np
import json
import pickle
import matplotlib.pyplot as plt

# %%
fp = "../colorado-opera/OPERA_L3_DSWx-HLS_T13SDC_20240116T175701Z_20240118T212241Z_S2A_30_v1.0_B08_SHAD.tif"
data = rasterio.open(fp).read()
plt.imshow(data[0,:,:], vmin=0, vmax=1)

# %%
fp = "../colorado-opera/OPERA_L3_DSWx-HLS_T13SDC_20240116T175701Z_20240118T212241Z_S2A_30_v1.0_B09_CLOUD.tif"
data = rasterio.open(fp).read()
plt.imshow(data[0,:,:], vmin=0, vmax=1)

# %%
np.unique(data)
# Out:
# array([  0,   1,   2,   3,   4,   5,   8, 255], dtype=uint8)
